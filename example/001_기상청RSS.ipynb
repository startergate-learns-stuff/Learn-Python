# %% [markdown]
# ### 기상청RSS
# - 기상청 날씨누리 http://www.weather.go.kr
# - [생활과 산업]-[서비스]-[인터넷]-[RSS]

# %% [markdown]
# ### 1. 데이터 가져오기

# %%
import urllib.request
import urllib.parse

# %%
RSS ="http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp"
#매개변수(쿼리)
values = { 'stnId': '156' }
query = urllib.parse.urlencode(values)

# %%
#요청 url 생성
url = RSS+"?"+query

# %%
data = urllib.request.urlopen(url).read()
text = data.decode('utf-8')

# %%
text
# Out:
# '<?xml version="1.0" encoding="utf-8" ?>\r\n<rss version="2.0">\r\n<channel>\r\n<title>기상청 육상 중기예보</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_05.jsp</link>\r\n<description>기상청 날씨 웹서비스</description>\r\n<language>ko</language>\r\n<generator>기상청</generator>\r\n<pubDate>2019년 01월 24일 (목)요일 06:00</pubDate>\r\n <item>\r\n<author>기상청</author>\r\n<category>육상중기예보</category>\r\n<title>전라남,북도 육상 중기예보 - 2019년 01월 24일 (목)요일 06:00 발표</title>\r\n<link>http://www.kma.go.kr/weather/forecast/mid-term_05.jsp</link>\r\n<guid>http://www.kma.go.kr/weather/forecast/mid-term_05.jsp</guid>\r\n<description>\r\n\t<header>\r\n\t\t<title>전라남,북도 육상중기예보</title>\r\n\t\t<tm>201901240600</tm>\r\n\t\t<wf><![CDATA[기압골의 영향으로 31일에는 비 또는 눈이 오겠고, 그 밖의 날은 고기압의 영향으로 대체로 맑은 날이 많겠습니다.<br />기온은 평년(최저기온: -5~-1℃, 최고기온: 5~7℃)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(0~1mm)보다 많겠습니다.<br />바다의 물결은 서해남부와 남해서부 전해상에서 28일과 31일~2월 2일에는 1.0~2.5m로 약간 높게 일겠으며, 그 밖의 날은 1.0~2.0m로 일겠습니다.<br /><br />* 대체로 맑은 날씨가 이어지면서 대기가 매우 건조해지겠으니, 산불 등 각종 화재예방에 각별히 유의하기 바랍니다.]]></wf>\r\n\t</header>\r\n\t<body>\r\n\t\t\t\t\r\n\r\n\t\t<location wl_ver="3">\r\n\t\t\t\t<province>광주ㆍ전라남도</province>\r\n\t\t\t\t<city>광주</city>\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-27 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-5</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>높음</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-27 12:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-5</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-28 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름많음</wf>\r\n\t\t\t\t\t<tmn>0</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-28 12:00</tmEf>\r\n\t\t\t\t\t<wf>구름많음</wf>\r\n\t\t\t\t\t<tmn>0</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-29 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-3</tmn>\r\n\t\t\t\t\t<tmx>8</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-29 12:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-3</tmn>\r\n\t\t\t\t\t<tmx>8</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-30 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-2</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-30 12:00</tmEf>\r\n\t\t\t\t\t<wf>구름많음</wf>\r\n\t\t\t\t\t<tmn>-2</tmn>\r\n\t\t\t\t\t<tmx>7</tmx>\r\n\t\t\t\t\t<reliability>낮음</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-31 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름많고 비/눈</wf>\r\n\t\t\t\t\t<tmn>1</tmn>\r\n\t\t\t\t\t<tmx>8</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A02</mode>\r\n\t\t\t\t\t<tmEf>2019-01-31 12:00</tmEf>\r\n\t\t\t\t\t<wf>구름많고 비/눈</wf>\r\n\t\t\t\t\t<tmn>1</tmn>\r\n\t\t\t\t\t<tmx>8</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A01</mode>\r\n\t\t\t\t\t<tmEf>2019-02-01 00:00</tmEf>\r\n\t\t\t\t\t<wf>구름조금</wf>\r\n\t\t\t\t\t<tmn>-1</tmn>\r\n\t\t\t\t\t<tmx>5</tmx>\r\n\t\t\t\t\t<reliability>보통</reliability>\r\n\t\t\t\t</data>\r\n\r\n\t\t\t\t\r\n\t\t\t\t<data>\r\n\t\t\t\t\t<mode>A01</mode>\r\n\t\t\t\t\t<tmEf>2019 ...

# %%
urllib.request.urlretrieve(url, 'data/rss.xml')
# Out:
# ('data/rss.xml', <http.client.HTTPMessage at 0x19799b28780>)

# %% [markdown]
# ### 2. 필요 정보 추출하기

# %%
# xml을 다루는 파이썬 표준모듈 임포트
from xml.etree import ElementTree

# %%
# parse() 함수로 파일을 읽어 들이고 ElementTree 객체 생성
tree = ElementTree.parse('data/rss.xml')
tree

# %%
#getroot() 메서드로 XML의 루트 요소 추출
root = tree.getroot()
root
# Out:
# <Element 'rss' at 0x00000197999B6598>

# %%
# findall('XPath')메서드로 요소 목록 추출
#weather = tree.findall('//data')
weather = root.findall('channel/item/description/body/location/data')
weather
# Out:
# [<Element 'data' at 0x0000019799B2A458>,
#  <Element 'data' at 0x0000019799B2A688>,
#  <Element 'data' at 0x0000019799B2A8B8>,
#  <Element 'data' at 0x0000019799B2AAE8>,
#  <Element 'data' at 0x0000019799B2AD18>,
#  <Element 'data' at 0x0000019799B2AF48>,
#  <Element 'data' at 0x0000019799B311D8>,
#  <Element 'data' at 0x0000019799B31408>,
#  <Element 'data' at 0x0000019799B31638>,
#  <Element 'data' at 0x0000019799B31868>,
#  <Element 'data' at 0x0000019799B31A98>,
#  <Element 'data' at 0x0000019799B31CC8>,
#  <Element 'data' at 0x0000019799B31EF8>,
#  <Element 'data' at 0x0000019799B36278>,
#  <Element 'data' at 0x0000019799B364A8>,
#  <Element 'data' at 0x0000019799B366D8>,
#  <Element 'data' at 0x0000019799B36908>,
#  <Element 'data' at 0x0000019799B36B38>,
#  <Element 'data' at 0x0000019799B36D68>,
#  <Element 'data' at 0x0000019799B36F98>,
#  <Element 'data' at 0x0000019799B39228>,
#  <Element 'data' at 0x0000019799B39458>,
#  <Element 'data' at 0x0000019799B39688>,
#  <Element 'data' at 0x0000019799B398B8>,
#  <Element 'data' at 0x0000019799B39AE8>,
#  <Element 'data' at 0x0000019799B39D18>,
#  <Element 'data' at 0x0000019799B3D098>,
#  <Element 'data' at 0x0000019799B3D2C8>,
#  <Element 'data' at 0x0000019799B3D4F8>,
#  <Element 'data' at 0x0000019799B3D728>,
#  <Element 'data' at 0x0000019799B3D958>,
#  <Element 'data' at 0x0000019799B3DB88>,
#  <Element 'data' at 0x0000019799B3DDB8>,
#  <Element 'data' at 0x0000019799B42048>,
#  <Element 'data' at 0x0000019799B42278>,
#  <Element 'data' at 0x0000019799B424A8>,
#  <Element 'data' at 0x0000019799B426D8>,
#  <Element 'data' at 0x0000019799B42908>,
#  <Element 'data' at 0x0000019799B42B38>,
#  <Element 'data' at 0x0000019799B42E58>,
#  <Element 'data' at 0x0000019799B460E8>,
#  <Element 'data' at 0x0000019799B46318>,
#  <Element 'data' at 0x0000019799B46548>,
#  <Element 'data' at 0x0000019799B46778>,
#  <Element 'data' at 0x0000019799B469A8>,
#  <Element 'data' at 0x0000019799B46BD8>,
#  <Element 'data' at 0x0000019799B46E08>,
#  <Element 'data' at 0x0000019799B4A098>,
#  <Element 'data' at 0x0000019799B4A2C8>,
#  <Element 'data' at 0x0000019799B4A4F8>,
#  <Element 'data' at 0x0000019799B4A728>,
#  <Element 'data' at 0x0000019799B4A958>,
#  <Element 'data' at 0x0000019799B4AC78>,
#  <Element 'data' at 0x0000019799B4AEA8>,
#  <Element 'data' at 0x0000019799B4E138>,
#  <Element 'data' at 0x0000019799B4E368>,
#  <Element 'data' at 0x0000019799B4E598>,
#  <Element 'data' at 0x0000019799B4E7C8>,
#  <Element 'data' at 0x0000019799B4E9F8>,
#  <Element 'data' at 0x0000019799B4EC28>,
#  <Element 'data' at 0x0000019799B4EE58>,
#  <Element 'data' at 0x0000019799B510E8>,
#  <Element 'data' at 0x0000019799B51318>,
#  <Element 'data' at 0x0000019799B51548>,
#  <Element 'data' at 0x0000019799B51778>,
#  <Element 'data' at 0x0000019799B51A98>,
#  <Element 'data' at 0x0000019799B51CC8>,
#  <Element 'data' at 0x0000019799B51EF8>,
#  <Element 'data' at 0x0000019799B54188>,
#  <Element 'data' at 0x0000019799B543B8>,
#  <Element 'data' at 0x0000019799B545E8>,
#  <Element 'data' at 0x0000019799B54818>,
#  <Element 'data' at 0x0000019799B54A48>,
#  <Element 'data' at 0x0000019799B54C78>,
#  <Element 'data' at 0x0000019799B54EA8>,
#  <Element 'data' at 0x0000019799B57138>,
#  <Element 'data' at 0x0000019799B57368>,
#  <Element 'data' at 0x0000019799B57598>,
#  <Element 'data' at 0x0000019799B578B8>,
#  <Element 'data' at 0x0000019799B57AE8>,
#  <Element 'data' at 0x0000019799B57D18>,
#  <Element 'data' at 0x0000019799B57F48>,
#  <Element 'data' at 0x0000019799B5E1D8>,
#  <Element 'data' at 0x0000019799B5E408>,
#  <Element 'data' at 0x0000019799B5E638>,
#  <Element 'data' at 0x0000019799B5E868>,
#  <Element 'data' at 0x0000019799B5EA98>,
#  <Element 'data' at 0x0000019799B5ECC8>,
#  <Element 'data' at 0x0000019799B5EEF8>,
#  <Element 'data' at 0x0000019799B61188>,
#  <Element 'data' at 0x0000019799B613B8>,
#  <Element 'data' at 0x0000019799B616D8>,
#  <Element 'data' at 0x0000019799B61908>,
#  <Element 'data' at 0x0000019799B61B38>,
#  <Element 'data' at 0x0000019799B61D68>,
#  <Element 'data' at 0x0000019799B61F98>,
#  <Element 'data' at 0x0000019799B67228>,
#  <Element 'data' at 0x0000019799B67458>,
#  <Element 'data' at 0x0000019799B67688>,
#  <Element 'data' at 0x0000019799B678B8>,
#  <Element 'data' at 0x0000019799B67AE8>,
#  <Element 'data' at 0x0000019799B67D18>,
#  <Element 'data' at 0x0000019799B67F48>,
#  <Element 'data' at 0x0000019799B6A1D8>,
#  <Element 'data' at 0x0000019799B6A4F8>,
#  <Element 'data' at 0x0000019799B6A728>,
#  <Element 'data' at 0x0000019799B6A958>,
#  <Element 'data' at 0x0000019799B6AB88>,
#  <Element 'data' at 0x0000019799B6ADB8>,
#  <Element 'data' at 0x0000019799B6D048>,
#  <Element 'data' at 0x0000019799B6D278>,
#  <Element 'data' at 0x0000019799B6D4A8>,
#  <Element 'data' at 0x0000019799B6D6D8>,
#  <Element 'data' at 0x0000019799B6D908>,
#  <Element 'data' at 0x0000019799B6DB38>,
#  <Element 'data' at 0x0000019799B6DD68>,
#  <Element 'data' at 0x0000019799B6DF98>,
#  <Element 'data' at 0x0000019799B71318>,
#  <Element 'data' at 0x0000019799B71548>,
#  <Element 'data' at 0x0000019799B71778>,
#  <Element 'data' at 0x0000019799B719A8>,
#  <Element 'data' at 0x0000019799B71BD8>,
#  <Element 'data' at 0x0000019799B71E08>,
#  <Element 'data' at 0x0000019799B75098>,
#  <Element 'data' at 0x0000019799B752C8>,
#  <Element 'data' at 0x0000019799B754F8>,
#  <Element 'data' at 0x0000019799B75728>,
#  <Element 'data' at 0x0000019799B75958>,
#  <Element 'data' at 0x0000019799B75B88>,
#  <Element 'data' at 0x0000019799B75DB8>,
#  <Element 'data' at 0x0000019799B78138>,
#  <Element 'data' at 0x0000019799B78368>,
#  <Element 'data' at 0x0000019799B78598>,
#  <Element 'data' at 0x0000019799B787C8>,
#  <Element 'data' at 0x0000019799B789F8>,
#  <Element 'data' at 0x0000019799B78C28>,
#  <Element 'data' at 0x0000019799B78E58>,
#  <Element 'data' at 0x0000019799B7D0E8>,
#  <Element 'data' at 0x0000019799B7D318>,
#  <Element 'data' at 0x0000019799B7D548>,
#  <Element 'data' at 0x0000019799B7D778>,
#  <Element 'data' at 0x0000019799B7D9A8>,
#  <Element 'data' at 0x0000019799B7DBD8>,
#  <Element 'data' at 0x0000019799B7DEF8>,
#  <Element 'data' at 0x0000019799B80188>,
#  <Element 'data' at 0x0000019799B803B8>,
#  <Element 'data' at 0x0000019799B805E8>,
#  <Element 'data' at 0x0000019799B80818>,
#  <Element 'data' at 0x0000019799B80A48>,
#  <Element 'data' at 0x0000019799B80C78>,
#  <Element 'data' at 0x0000019799B80EA8>,
#  <Element 'data' at 0x0000019799B85138>,
#  <Element 'data' at 0x0000019799B85368>,
#  <Element 'data' at 0x0000019799B85598>,
#  <Element 'data' at 0x0000019799B857C8>,
#  <Element 'data' at 0x0000019799B859F8>,
#  <Element 'data' at 0x0000019799B85D18>,
#  <Element 'data' at 0x0000019799B85F48>,
#  <Element 'data' at 0x0000019799B881D8>,
#  <Element 'data' at 0x0000019799B88408>,
#  <Element 'data' at 0x0000019799B88638>,
#  <Element 'data' at 0x0000019799B88868>,
#  <Element 'data' at 0x0000019799B88A98>,
#  <Element 'data' at 0x0000019799B88CC8>,
#  <Element 'data' at 0x0000019799B88EF8>,
#  <Element 'data' at 0x0000019799B8B188>,
#  <Element 'data' at 0x0000019799B8B3B8>,
#  <Element 'data' at 0x0000019799B8B5E8>,
#  <Element 'data' at 0x0000019799B8B818>,
#  <Element 'data' at 0x0000019799B8BB38>,
#  <Element 'data' at 0x0000019799B8BD68>,
#  <Element 'data' at 0x0000019799B8BF98>,
#  <Element 'data' at 0x0000019799B91228>,
#  <Element 'data' at 0x0000019799B91458>,
#  <Element 'data' at 0x0000019799B91688>,
#  <Element 'data' at 0x0000019799B918B8>,
#  <Element 'data' at 0x0000019799B91AE8>,
#  <Element 'data' at 0x0000019799B91D18>,
#  <Element 'data' at 0x0000019799B91F48>,
#  <Element 'data' at 0x0000019799B941D8>,
#  <Element 'data' at 0x0000019799B94408>,
#  <Element 'data' at 0x0000019799B94638>,
#  <Element 'data' at 0x0000019799B94958>,
#  <Element 'data' at 0x0000019799B94B88>,
#  <Element 'data' at 0x0000019799B94DB8>,
#  <Element 'data' at 0x0000019799B99048>,
#  <Element 'data' at 0x0000019799B99278>,
#  <Element 'data' at 0x0000019799B994A8>,
#  <Element 'data' at 0x0000019799B996D8>,
#  <Element 'data' at 0x0000019799B99908>,
#  <Element 'data' at 0x0000019799B99B38>,
#  <Element 'data' at 0x0000019799B99D68>,
#  <Element 'data' at 0x0000019799B99F98>,
#  <Element 'data' at 0x0000019799B9C228>,
#  <Element 'data' at 0x0000019799B9C458>,
#  <Element 'data' at 0x0000019799B9C778>,
#  <Element 'data' at 0x0000019799B9C9A8>,
#  <Element 'data' at 0x0000019799B9CBD8>,
#  <Element 'data' at 0x0000019799B9CE08>,
#  <Element 'data' at 0x0000019799BA0098>,
#  <Element 'data' at 0x0000019799BA02C8>,
#  <Element 'data' at 0x0000019799BA04F8>,
#  <Element 'data' at 0x0000019799BA0728>,
#  <Element 'data' at 0x0000019799BA0958>,
#  <Element 'data' at 0x0000019799BA0B88>,
#  <Element 'data' at 0x0000019799BA0DB8>,
#  <Element 'data' at 0x0000019799BA4048>,
#  <Element 'data' at 0x0000019799BA4278>,
#  <Element 'data' at 0x0000019799BA4598>,
#  <Element 'data' at 0x0000019799BA47C8>,
#  <Element 'data' at 0x0000019799BA49F8>,
#  <Element 'data' at 0x0000019799BA4C28>,
#  <Element 'data' at 0x0000019799BA4E58>,
#  <Element 'data' at 0x0000019799BA90E8>,
#  <Element 'data' at 0x0000019799BA9318>,
#  <Element 'data' at 0x0000019799BA9548>,
#  <Element 'data' at 0x0000019799BA9778>,
#  <Element 'data' at 0x0000019799BA99A8>,
#  <Element 'data' at 0x0000019799BA9BD8>,
#  <Element 'data' at 0x0000019799BA9E08>,
#  <Element 'data' at 0x0000019799BAD098>,
#  <Element 'data' at 0x0000019799BAD3B8>,
#  <Element 'data' at 0x0000019799BAD5E8>,
#  <Element 'data' at 0x0000019799BAD818>,
#  <Element 'data' at 0x0000019799BADA48>,
#  <Element 'data' at 0x0000019799BADC78>,
#  <Element 'data' at 0x0000019799BADEA8>,
#  <Element 'data' at 0x0000019799BB0138>,
#  <Element 'data' at 0x0000019799BB0368>,
#  <Element 'data' at 0x0000019799BB0598>,
#  <Element 'data' at 0x0000019799BB07C8>,
#  <Element 'data' at 0x0000019799BB09F8>,
#  <Element 'data' at 0x0000019799BB0C28>,
#  <Element 'data' at 0x0000019799BB0E58>,
#  <Element 'data' at 0x0000019799BB41D8>,
#  <Element 'data' at 0x0000019799BB4408>,
#  <Element 'data' at 0x0000019799BB4638>,
#  <Element 'data' at 0x0000019799BB4868>,
#  <Element 'data' at 0x0000019799BB4A98>,
#  <Element 'data' at 0x0000019799BB4CC8>,
#  <Element 'data' at 0x0000019799BB4EF8>,
#  <Element 'data' at 0x0000019799BB8188>,
#  <Element 'data' at 0x0000019799BB83B8>,
#  <Element 'data' at 0x0000019799BB85E8>,
#  <Element 'data' at 0x0000019799BB8818>,
#  <Element 'data' at 0x0000019799BB8A48>,
#  <Element 'data' at 0x0000019799BB8C78>,
#  <Element 'data' at 0x0000019799BB8F98>,
#  <Element 'data' at 0x0000019799BBB228>,
#  <Element 'data' at 0x0000019799BBB458>,
#  <Element 'data' at 0x0000019799BBB688>,
#  <Element 'data' at 0x0000019799BBB8B8>,
#  <Element 'data' at 0x0000019799BBBAE8>,
#  <Element 'data' at 0x0000019799BBBD18>,
#  <Element 'data' at 0x0000019799BBBF48>,
#  <Element 'data' at 0x0000019799BC01D8>,
#  <Element 'data' at 0x0000019799BC0408>,
#  <Element 'data' at 0x0000019799BC0638>,
#  <Element 'data' at 0x0000019799BC0868>,
#  <Element 'data' at 0x0000019799BC0A98>,
#  <Element 'data' at 0x0000019799BC0DB8>,
#  <Element 'data' at 0x0000019799BC6048>,
#  <Element 'data' at 0x0000019799BC6278>,
#  <Element 'data' at 0x0000019799BC64A8>,
#  <Element 'data' at 0x0000019799BC66D8>,
#  <Element 'data' at 0x0000019799BC6908>,
#  <Element 'data' at 0x0000019799BC6B38>,
#  <Element 'data' at 0x0000019799BC6D68>,
#  <Element 'data' at 0x0000019799BC6F98>,
#  <Element 'data' at 0x0000019799BC9228>,
#  <Element 'data' at 0x0000019799BC9458>,
#  <Element 'data' at 0x0000019799BC9688>,
#  <Element 'data' at 0x0000019799BC98B8>,
#  <Element 'data' at 0x0000019799BC9BD8>,
#  <Element 'data' at 0x0000019799BC9E08>,
#  <Element 'data' at 0x0000019799BCC098>,
#  <Element 'data' at 0x0000019799BCC2C8>,
#  <Element 'data' at 0x0000019799BCC4F8>,
#  <Element 'data' at 0x0000019799BCC728>,
#  <Element 'data' at 0x0000019799BCC958>,
#  <Element 'data' at 0x0000019799BCCB88>,
#  <Element 'data' at 0x0000019799BCCDB8>,
#  <Element 'data' at 0x0000019799BD0048>,
#  <Element 'data' at 0x0000019799BD0278>,
#  <Element 'data' at 0x0000019799BD04A8>,
#  <Element 'data' at 0x0000019799BD06D8>,
#  <Element 'data' at 0x0000019799BD09F8>,
#  <Element 'data' at 0x0000019799BD0C28>,
#  <Element 'data' at 0x0000019799BD0E58>,
#  <Element 'data' at 0x0000019799BD30E8>,
#  <Element 'data' at 0x0000019799BD3318>,
#  <Element 'data' at 0x0000019799BD3548>,
#  <Element 'data' at 0x0000019799BD3778>,
#  <Element 'data' at 0x0000019799BD39A8>,
#  <Element 'data' at 0x0000019799BD3BD8>,
#  <Element 'data' at 0x0000019799BD3E08>,
#  <Element 'data' at 0x0000019799BD8098>,
#  <Element 'data' at 0x0000019799BD82C8>,
#  <Element 'data' at 0x0000019799BD84F8>,
#  <Element 'data' at 0x0000019799BD8818>,
#  <Element 'data' at 0x0000019799BD8A48>,
#  <Element 'data' at 0x0000019799BD8C78>,
#  <Element 'data' at 0x0000019799BD8EA8>,
#  <Element 'data' at 0x0000019799BDC138>,
#  <Element 'data' at 0x0000019799BDC368>,
#  <Element 'data' at 0x0000019799BDC598>,
#  <Element 'data' at 0x0000019799BDC7C8>,
#  <Element 'data' at 0x0000019799BDC9F8>,
#  <Element 'data' at 0x0000019799BDCC28>,
#  <Element 'data' at 0x0000019799BDCE58>,
#  <Element 'data' at 0x0000019799BE00E8>,
#  <Element 'data' at 0x0000019799BE0318>]

# %% [markdown]
# - XPath : XML의 특정 요소를 지정하기 위한 언어
# - 참고사이트 https://www.w3schools.com/xml/xpath_syntax.asp

# %%
result =[]
for item in weather:
    tm_ef = item.find('tmEf').text
    wf = item.find('wf').text
    result.append({'tm':tm_ef, 'wf':wf})
    print(tm_ef, wf)
# Out:
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금
# 2019-01-27 00:00 구름조금
# 2019-01-27 12:00 구름조금
# 2019-01-28 00:00 구름많음
# 2019-01-28 12:00 구름많음
# 2019-01-29 00:00 구름조금
# 2019-01-29 12:00 구름조금
# 2019-01-30 00:00 구름조금
# 2019-01-30 12:00 구름많음
# 2019-01-31 00:00 구름많고 비/눈
# 2019-01-31 12:00 구름많고 비/눈
# 2019-02-01 00:00 구름조금
# 2019-02-02 00:00 구름조금
# 2019-02-03 00:00 구름조금

# %% [markdown]
# ### 3. DB 저장

# %%
import sqlite3

conn = sqlite3.connect('/data/weather.db')
cur = conn.cursor()

# %%
cur.execute('DROP TABLE IF EXISTS wt')

# %%
cur.execute('CREATE TABLE wt (date text, status text)')

# %%
cur.executemany('INSERT INTO wt values (:tm, :wf)',result )

# %%
cur.execute('select * from wt limit 5')

# %%
table = cur.fetchall()
for record in table:
    print("날짜 : %s  날씨 : %s" % record)
# Out:
# 날짜 : 2019-01-27 00:00  날씨 : 구름조금
# 날짜 : 2019-01-27 12:00  날씨 : 구름조금
# 날짜 : 2019-01-28 00:00  날씨 : 구름많음
# 날짜 : 2019-01-28 12:00  날씨 : 구름많음
# 날짜 : 2019-01-29 00:00  날씨 : 구름조금

# %%
conn.commit()
conn.close()
